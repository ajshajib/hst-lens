# %% [markdown]
#     Author: Anowar J. Shajib (ajshajib@astro.ucla.edu)
#     Updated: April 17, 2019.

# %% [markdown]
# # HST data reduction for WFC3 IR

# %% [markdown]
# ## Setup

# %%
import glob
import shutil
import os
import matplotlib.pyplot as plt
import numpy as np

from astropy.io import fits
from astropy.table import Table
from astroquery.mast import Observations
from astropy.visualization import LogStretch
from astropy.visualization import ImageNormalize
from astropy.visualization import LinearStretch
from astropy import wcs
from drizzlepac import astrodrizzle
from drizzlepac import tweakreg

# %matplotlib inline
# Out:
# The following task in the stsci.skypac package can be run with TEAL:
#                                     skymatch
# The following tasks in the drizzlepac package can be run with TEAL:
#     astrodrizzle       imagefindpars           mapreg              photeq
#      pixreplace           pixtopix            pixtosky        refimagefindpars
#      resetbits          runastrodriz          skytopix           tweakback
#       tweakreg           updatenpol

# %% [markdown]
# #### Specify raw data and output directories.

# %%
object_name = 'DESJ2038-4008'
band = 'F160W'

raw_data_dir = '../raw_data/F160W'
output_data_dir = '../reduced_data'

# %%
# create temp working directory in output_dir
temp_dir = output_data_dir+'/temp'

if os.path.isdir(temp_dir):
    shutil.rmtree(temp_dir)
    
os.mkdir(temp_dir)

# move raw data files to temporary directory to work on
for file in glob.glob(os.path.join(raw_data_dir,"*.fits")):
        shutil.copy2(file, temp_dir)

# %% [markdown]
# ## See dithering

# %%
flt_files = glob.glob(temp_dir+'/*flt.fits')

plate_scale = fits.getval(flt_files[0], 'idcscale',ext=1)
print('Plate scale: {:>6.4f}'.format(plate_scale))
postarg1 = np.empty(len(flt_files), dtype=np.float)
postarg2 = np.empty(len(flt_files), dtype=np.float)
x_phase = np.empty(len(flt_files), dtype=np.float)
y_phase = np.empty(len(flt_files), dtype=np.float)

for i, im in enumerate(flt_files):
    with fits.open(im) as hdu:
        postarg1[i] = hdu[0].header['postarg1']
        postarg2[i] = hdu[0].header['postarg2']
        x_phase[i] = abs(np.modf(postarg1[i] / plate_scale)[0])
        y_phase[i] = abs(np.modf(postarg2[i] / plate_scale)[0])
        
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

ax[0].plot(postarg1, postarg2, 'k+-', ms=15, lw=1)
ax[0].set_xlabel('arcsec', fontsize='large')
ax[0].set_ylabel('arcsec', fontsize='large')
ax[0].set_title('Dithering on sky')

ax[1].plot(x_phase, y_phase, 'k+-', ms=15, lw=1)
ax[1].set_xlim(-0.05, 1)
ax[1].set_ylim(-0.05, 1)
ax[1].set_xlabel('X pixel phase', fontsize='large')
ax[1].set_ylabel('Y pixel phase', fontsize='large')
ax[1].set_title('Dithering in pixel phase')
# Out:
# Plate scale: 0.1283
# Text(0.5, 1.0, 'Dithering in pixel phase')

# %% [markdown]
# This is 4-point IR-blob dithering. See [here](http://www.stsci.edu/hst/wfc3/documents/ISRs/WFC3-2010-09.pdf) for details.

# %% [markdown]
# ## Check alignment
#
# To generate source lists for matching, the TweakReg parameter `conv_width` should be set to approximately twice the FWHM of the PSF, ~2.5 pixels for IR observations. TweakReg will automatically compute the standard deviation of the sky background (`skysigma`), so the number of sources in each catalog may be controlled simply by changing the ‘threshold’ parameter.
#
# In this example, TweakReg is run in ‘non-interactive’ mode (`interactive='False'`) so that the astrometric fit residuals and vectors diagrams will be saved as png files in the local directory for inspection. Once the parameters have been fine-tuned and the fit looks adequate, you may run TweakReg a second time (see below) to update the image header WCS keywords by setting the parameter `updatehdr` to `True`.

# %%
tweakreg.TweakReg(temp_dir+'/*flt.fits',
                  imagefindcfg={'threshold': 50, 'conv_width': 2.5},
                  expand_refcat=True,
                  enforce_user_order=False,
                  shiftfile=True,
                  outshifts=temp_dir+'/shift160_flt.txt',
                  searchrad=2.0,
                  ylimit=0.3,
                  updatehdr=False,
                  reusename=True,
                  wcsname='IR_FLT',
                  interactive=False)
# Out:
# Setting up logfile :  tweakreg.log
# TweakReg Version 1.4.7(18-April-2018) started at: 23:17:59.357 (17/04/2019)
#
# Version Information
# --------------------
# Python Version [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)]
# 3.6.7 | packaged by conda-forge | (default, Feb 28 2019, 02:16:08)
# numpy Version -> 1.16.2
# astropy Version -> 3.1.2
# stwcs Version -> 1.4.2
#
# Finding shifts for:
#     /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits
#     /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits
#     /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits
#     /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits
#
# ===  Source finding for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits':
#   #  Source finding for '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits', EXT=('SCI', 1) started at: 23:17:59.470 (17/04/2019)
#      Found 35 objects.
# ===  FINAL number of objects in image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits': 35
#
# ===  Source finding for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits':
#   #  Source finding for '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits', EXT=('SCI', 1) started at: 23:17:59.642 (17/04/2019)
#      Found 34 objects.
# ===  FINAL number of objects in image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits': 34
#
# ===  Source finding for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits':
#   #  Source finding for '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits', EXT=('SCI', 1) started at: 23:17:59.794 (17/04/2019)
#      Found 34 objects.
# ===  FINAL number of objects in image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits': 34
#
# ===  Source finding for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits':
#   #  Source finding for '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits', EXT=('SCI', 1) started at: 23:17:59.94 (17/04/2019)
#      Found 42 objects.
# ===  FINAL number of objects in image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits': 42
#
#
# ===============================================================
# Performing alignment in the projection plane defined by the WCS
# derived from '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits'
# ===============================================================
#
#
# ====================
# Performing fit for: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits
#
# Matching sources from '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits' with sources from reference image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.5945415624456896 -0.5945415624456896
#     with significance of  146.4581851587681 and  22.0  matches
# Found 22 matches for /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits...
# Computed  rscale  fit for  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits :
# XSH: -0.0388  YSH: -0.0488    ROT: 0.002090254443    SCALE: 0.999996
# XRMS: 0.058    YRMS: 0.039
#
# RMS_RA: 1.9e-06 (deg)   RMS_DEC: 2e-06 (deg)
#
# Final solution based on  22  objects.
# wrote XY data to:  idgc08iiq_flt_catalog_fit.match
# Total # points:  22
# # of points after clipping:  22
# Total # points:  22
# # of points after clipping:  22
# Adding 12 new sources to the reference catalog for a total of 47 sources.
#
# ====================
# Performing fit for: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits
#
# Matching sources from '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits' with sources from reference image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.5945415624456896 -0.5945415624456896
#     with significance of  143.09088021254186 and  21.0  matches
# Found 21 matches for /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits...
# Computed  rscale  fit for  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits :
# XSH: -0.0842  YSH: -0.0433    ROT: 0.0004240605146    SCALE: 1.000010
# XRMS: 0.056    YRMS: 0.038
#
# RMS_RA: 1.9e-06 (deg)   RMS_DEC: 1.9e-06 (deg)
#
# Final solution based on  21  objects.
# wrote XY data to:  idgc08ikq_flt_catalog_fit.match
# Total # points:  21
# # of points after clipping:  21
# Total # points:  21
# # of points after clipping:  21
# Adding 13 new sources to the reference catalog for a total of 60 sources.
#
# ====================
# Performing fit for: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits
#
# Matching sources from '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits' with sources from reference image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits'
# Computing initial guess for X and Y shifts...
# Found initial X and Y shifts of  -0.668615636519764 -0.6315785994827277
#     with significance of  843.0747297837837 and  26.0  matches
# Found 27 matches for /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits...
# Computed  rscale  fit for  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits :
# XSH: -0.0906  YSH: -0.0436    ROT: 0.001640536727    SCALE: 0.999969
# XRMS: 0.08    YRMS: 0.036
#
# RMS_RA: 1.8e-06 (deg)   RMS_DEC: 2.8e-06 (deg)
#
# Final solution based on  25  objects.
# wrote XY data to:  idgc08ilq_flt_catalog_fit.match
# Total # points:  25
# # of points after clipping:  25
# Total # points:  25
# # of points after clipping:  25
# Adding 15 new sources to the reference catalog for a total of 75 sources.
# Writing out shiftfile : ../reduced_data/temp/shift160_flt.txt
# Trailer file written to:  tweakreg.log

# %% [markdown]
# The $\Delta X$ and $\Delta Y$ in above figure should be $\lesssim0.1$ pixels. Otherwise, `AstroDrizzle` can't correctly detect cosmic rays.
#
# Look the actual RMS values of $\Delta X$ and $\Delta Y$ in the table below.

# %%
shift_table = Table.read(temp_dir+'/shift160_flt.txt',
                         format='ascii.no_header', 
                         names=['file', 'dx', 'dy', 'rot', 'scale', 'xrms', 'yrms'])

formats = ['.2f', '.2f', '.3f', '.5f', '.2f', '.2f']
for i, col in enumerate(shift_table.colnames[1:]):
    shift_table[col].format = formats[i]
shift_table
# Out:
# <Table length=4>
#                                            file                                            ...
#                                           str90                                            ...
# ------------------------------------------------------------------------------------------ ...
# /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits ...
# /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits ...
# /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits ...
# /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits ...

# %% [markdown]
# The pointing is accurate to ~0.07 IR pixel (~9 mas).

# %% [markdown]
# ## Drizzle

# %% [markdown]
# Up-the-ramp sampling with calwf3 already removes cosmic rays in IR. But, there are still some odd pixels that stand out. So, we don't skip steps 3, 4, 5, and 6. Warm pixels are flagged with DQ=64, and we include them back as good pixels.

# %%
output = output_data_dir+'/'+object_name+'_'+band

astrodrizzle.AstroDrizzle(temp_dir+'/*flt.fits',
                          
                          # other parameters
                          output=output,
                          build=False, # if False, outputs sci, wht, and ctx into separate files
                          #resetbits=0, # default 4096
                          
                          # state of input files
                          preserve=False, # default True
                          clean=True, # default False
                          
                          # step 1: static mask
                          static=True,
                          static_sig=4., #default 4.
                          
                          # step 2: sky subtraction
                          skysub=False,
                          
                          # step 3: drizzle separate images
                          driz_separate=True,
                          driz_sep_kernel='turbo', # default 'turbo'
                          driz_sep_pixfrac=1., # default 1.
                          driz_sep_bits=0, # default 0
                          
                          # step 3a: custom WCS for separate outputs
                          driz_sep_scale=None, # default None
                          
                          # step 4: create median image
                          median=True, # default True
                          
                          # step 5: blot back the median image
                          blot=True, # default True
                          
                          # step 6: remove cosmic rays with deriv, driz_cr
                          driz_cr=True, # default True
                          driz_cr_corr=False, # default False
                          driz_cr_scale='2.2 0.7', # default '1.2 0.7'
                          #current value doesn't falsely detect
                          # the central pixels of the quasar images as CR. 
                          #driz_cr_snr='2. 1.5',
                          
                          # step 7: drizzle final combined image
                          driz_combine=True,
                          final_wht_type='EXP',
                          final_kernel='gaussian',
                          final_wt_scl='exptime',
                          final_pixfrac=0.7,
                          final_bits=64, # default 0, including warm pixels (DQ=64) back
                          
                          # step 7a: custom wcs for final output
                          final_wcs=True, # default False
                          final_rot=0,
                          final_scale=0.08,
                          
                          # instrument parameters
                          
                          # advanced parameters
)
# Out:
# Setting up logfile :  astrodrizzle.log
# AstroDrizzle Version 2.2.6 (2018-11-02 15:37:13 -0400) started at: 23:18:03.055 (17/04/2019)
#
# ==== Processing Step  Initialization  started at  23:18:03.060 (17/04/2019)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 309.51370832183335  -40.134754956202634
# CRPIX : 833.6650483304018  948.7986298496229
# CD1_1 CD1_2  : -2.222222222222222e-05  1.8962947213334647e-23
# CD2_1 CD2_2  : 4.161435315295294e-23  2.222222222222222e-05
# NAXIS : 1668  1895
# ********************************************************************************
# *
# *  Estimated memory usage:  up to 176 Mb.
# *  Output image size:       1668 X 1895 pixels.
# *  Output image file:       ~ 36 Mb.
# *  Cores available:         4
# *
# ********************************************************************************
# ==== Processing Step  Initialization  finished at  23:18:04.023 (17/04/2019)
#
# ==== Processing Step  Static Mask  started at  23:18:04.025 (17/04/2019)
# ==== Processing Step  Static Mask  finished at  23:18:04.147 (17/04/2019)
#
# ==== Processing Step  Subtract Sky  started at  23:18:04.14 (17/04/2019)
# ==== Processing Step  Subtract Sky  finished at  23:18:04.274 (17/04/2019)
#
# ==== Processing Step  Separate Drizzle  started at  23:18:04.275 (17/04/2019)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 309.51370832183335  -40.134754956202634
# CRPIX : 573.5  500.0
# CD1_1 CD1_2  : -1.2766503206132967e-06  -3.560211855470528e-05
# CD2_1 CD2_2  : -3.560211855470528e-05  1.2766503206132967e-06
# NAXIS : 1147  1000
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_single_sci.fits
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_single_sci.fits
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_single_sci.fits
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_single_sci.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_single_sci.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_single_sci.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_single_sci.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_single_sci.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_single_wht.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_single_wht.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_single_wht.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_single_wht.fits
# ==== Processing Step  Separate Drizzle  finished at  23:18:05.308 (17/04/2019)
#
# ==== Processing Step  Create Median  started at  23:18:05.315 (17/04/2019)
# reference sky value for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits' is 318.72315535942784
# reference sky value for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits' is 300.7198906180829
# reference sky value for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits' is 368.68115023744076
# reference sky value for image '/Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits' is 357.8276462947462
# Saving output median image to: '../reduced_data/DESJ2038-4008_F160W_med.fits'
# ==== Processing Step  Create Median  finished at  23:18:06.1 (17/04/2019)
#
# ==== Processing Step  Blot  started at  23:18:06.184 (17/04/2019)
#     Blot: creating blotted image:  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_sci1_blt.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_sci1_blt.fits
#     Blot: creating blotted image:  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_sci1_blt.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_sci1_blt.fits
#     Blot: creating blotted image:  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_sci1_blt.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_sci1_blt.fits
#     Blot: creating blotted image:  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_flt.fits[sci,1]
# Using default C-based coordinate transformation...
# -Generating simple FITS output: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_sci1_blt.fits
# Writing out image to disk: /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_sci1_blt.fits
# ==== Processing Step  Blot  finished at  23:18:07.385 (17/04/2019)
#
# ==== Processing Step  Driz_CR  started at  23:18:07.38 (17/04/2019)
# Creating output :  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08igq_sci1_crmask.fits
# Creating output :  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ikq_sci1_crmask.fits
# Creating output :  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08iiq_sci1_crmask.fits
# Creating output :  /Users/ajshajib/Research/time_delay_cosmography/J2038/reduced_data/temp/idgc08ilq_sci1_crmask.fits
# ==== Processing Step  Driz_CR  finished at  23:18:08.510 (17/04/2019)
#
# ==== Processing Step  Final Drizzle  started at  23:18:08.522 (17/04/2019)
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 309.51370832183335  -40.134754956202634
# CRPIX : 833.6650483304018  948.7986298496229
# CD1_1 CD1_2  : -2.222222222222222e-05  1.8962947213334647e-23
# CD2_1 CD2_2  : 4.161435315295294e-23  2.222222222222222e-05
# NAXIS : 1668  1895
# -Generating simple FITS output: ../reduced_data/DESJ2038-4008_F160W_drz_sci.fits
# Writing out image to disk: ../reduced_data/DESJ2038-4008_F160W_drz_sci.fits
# Writing out image to disk: ../reduced_data/DESJ2038-4008_F160W_drz_wht.fits
# Writing out image to disk: ../reduced_data/DESJ2038-4008_F160W_drz_ctx.fits
# ==== Processing Step  Final Drizzle  finished at  23:18:12.014 (17/04/2019)
#
#
# AstroDrizzle Version 2.2.6 is finished processing at 23:18:12.016 (17/04/2019).
#
#
#    --------------------          --------------------
#                    Step          Elapsed time
#    --------------------          --------------------
#
#          Initialization          0.9633 sec.
#             Static Mask          0.1212 sec.
#            Subtract Sky          0.1259 sec.
#        Separate Drizzle          1.0326 sec.
#           Create Median          0.8673 sec.
#                    Blot          1.2012 sec.
#                 Driz_CR          1.1233 sec.
#           Final Drizzle          3.4913 sec.
#    ====================          ====================
#                   Total          8.9262 sec.
# Trailer file written to:  astrodrizzle.log

# %% [markdown]
# ## Check drizzled image

# %%
# %matplotlib inline

sci_file = output+'_drz_sci.fits'
wht_file = output+'_drz_wht.fits'

with fits.open(sci_file) as hdu:
    im_wcs = wcs.WCS(hdu[0].header)
    sci = hdu[0].data

with fits.open(wht_file) as hdu:
    wht = hdu[0].data
    
radec_lims = wcs.utils.pixel_to_skycoord([865, 965], [795, 895], im_wcs)
        
norm = ImageNormalize(sci, vmin=-0.2, vmax=25, stretch=LogStretch())
fig, ax = plt.subplots(1, 2, figsize=(16, 8), subplot_kw={'projection':im_wcs})
ax[0].imshow(sci, norm=norm, cmap='viridis', origin='lower')
ax[1].imshow(wht, cmap='plasma', origin='lower')

ax[0].set_xlim(radec_lims.to_pixel(im_wcs)[0])
ax[0].set_ylim(radec_lims.to_pixel(im_wcs)[1])

ax[1].set_xlim(radec_lims.to_pixel(im_wcs)[0])
ax[1].set_ylim(radec_lims.to_pixel(im_wcs)[1])
# Out:
# (794.9999999998162, 894.999999999904)

# %% [markdown]
# ## Check bad pixels and cosmic ray flagging

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 12))

for i, flt_file in enumerate(flt_files):
    row = int(i/2)
    col = i%2
    
    with fits.open(flt_file) as hdu:
        flt_wcs = wcs.WCS(hdu[1].header)
        data = hdu[1].data
        dq = hdu[3].data
    
    ax[row, col].matshow(np.log10(data), origin='right')
    ax[row, col].plot(*np.argwhere(dq >= 4096).T[::-1], 'rx', ls='None', markersize=7)
    ax[row, col].plot(*np.argwhere(dq & (1 << int(np.log2(64)))).T[::-1], 'yo', ls='None', markersize=7)
    ax[row, col].plot(*np.argwhere(dq != 0).T[::-1], 'k+', ls='None', markersize=7)
    
    #ax[row, col].set_xlim(500, 650)
    #ax[row, col].set_ylim(500, 650)
    ax[row, col].set_xlim(radec_lims.to_pixel(flt_wcs)[0])
    ax[row, col].set_ylim(radec_lims.to_pixel(flt_wcs)[1])
    ax[row, col].set(adjustable='box-forced', aspect='equal')
    
    
fig.tight_layout()
# Out:
# /Users/ajshajib/anaconda3/envs/astroconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':
# /Users/ajshajib/anaconda3/envs/astroconda/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in log10
#   if sys.path[0] == '':

# %% [markdown]
# Red crosses are flagged pixels as comsic rays. Black plus symbols are all bad pixels. Yellow dots are warm pixels that we added back as good pixels.

# %% [markdown]
# ## Clean up

# %%
# Remove all the files in the notebook directory with the following suffixes.
files_to_clean = ['coo', 'png', 'fits', 'match', 'log', 'list']

for suffix in files_to_clean:
    filelist=glob.glob("./*.{}".format(suffix))

    for file in filelist:
        os.remove(file)
        
# Remove temporary directory.
if os.path.isdir(temp_dir):
    shutil.rmtree(temp_dir)
